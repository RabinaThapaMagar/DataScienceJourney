# %% [markdown]
# # Encoding

# %%
import pandas as pd

# %%
Encoding:
One hot encoding:
One-hot encoding is a method for converting categorical data into a numerical format that can be provided to machine learning algorithms. 
It creates binary (0 or 1) columns for each category level of a feature.

# %%
data = pd.read_csv('Salary_Data.csv')
data.head()
# Out:
#     Age  Gender Education Level          Job Title  Years of Experience  \
# 0  32.0    Male      Bachelor's  Software Engineer                  5.0
# 1  28.0  Female        Master's       Data Analyst                  3.0
# 2  45.0    Male             PhD     Senior Manager                 15.0
# 3  36.0  Female      Bachelor's    Sales Associate                  7.0
# 4  52.0    Male        Master's           Director                 20.0
#
#      Salary
# 0   90000.0
# 1   65000.0
# 2  150000.0
# 3   60000.0
# 4  200000.0

# %%
data.dropna(inplace=True)

# %%
data['Gender'].unique()
# Out:
# array(['Male', 'Female', 'Other'], dtype=object)

# %%
df =pd.get_dummies(data,columns= ['Gender'],drop_first = True, dtype=int)
df
#drop_first garera gender_female hatyo auta value janxa
#drop_first or drop_last garna jaruri xa kina bhane
# Out:
#        Age    Education Level              Job Title  Years of Experience  \
# 0     32.0         Bachelor's      Software Engineer                  5.0
# 1     28.0           Master's           Data Analyst                  3.0
# 2     45.0                PhD         Senior Manager                 15.0
# 3     36.0         Bachelor's        Sales Associate                  7.0
# 4     52.0           Master's               Director                 20.0
# ...    ...                ...                    ...                  ...
# 6699  49.0                PhD  Director of Marketing                 20.0
# 6700  32.0        High School        Sales Associate                  3.0
# 6701  30.0  Bachelor's Degree      Financial Manager                  4.0
# 6702  46.0    Master's Degree      Marketing Manager                 14.0
# 6703  26.0        High School        Sales Executive                  1.0
#
#         Salary  Gender_Male  Gender_Other
# ...

# %%
Categorial
  Ordinal: order example: bachelor, master, php etc ie order hunxa yesto ma (label encoding laune)
gender ma male ra female matra vaye ni ie binary (label encoding launa milthyo)

Nominal: order hudaina ex Gender, color ie (One hot encoding)

# %%
Education level ma garda categorial bhitra ko ordinal ho so label encoding lagaune

# %% [markdown]
# # for Education Level(Ordinal)

# %%
data = pd.read_csv('Salary_Data.csv')
data.head()
# Out:
#     Age  Gender Education Level          Job Title  Years of Experience  \
# 0  32.0    Male      Bachelor's  Software Engineer                  5.0
# 1  28.0  Female        Master's       Data Analyst                  3.0
# 2  45.0    Male             PhD     Senior Manager                 15.0
# 3  36.0  Female      Bachelor's    Sales Associate                  7.0
# 4  52.0    Male        Master's           Director                 20.0
#
#      Salary
# 0   90000.0
# 1   65000.0
# 2  150000.0
# 3   60000.0
# 4  200000.0

# %%
data.dropna(inplace = True)

# %%
#To rename name of column
data = data.rename(columns={
    'Education Level':'Education'
})

# %%
data.head()
# Out:
#     Age  Gender   Education          Job Title  Years of Experience    Salary
# 0  32.0    Male  Bachelor's  Software Engineer                  5.0   90000.0
# 1  28.0  Female    Master's       Data Analyst                  3.0   65000.0
# 2  45.0    Male         PhD     Senior Manager                 15.0  150000.0
# 3  36.0  Female  Bachelor's    Sales Associate                  7.0   60000.0
# 4  52.0    Male    Master's           Director                 20.0  200000.0

# %%
data['Education'].unique()
# Out:
# array(["Bachelor's", "Master's", 'PhD', "Bachelor's Degree",
#        "Master's Degree", 'High School', 'phD'], dtype=object)

# %%
#Inconsistency ie bacherlo ra bachelor degree yesto xa bhane inconsistencey yesto lai milaune ie kasaile bachelor halyo ra kasari bachelor degree halyo data entry garda 
# so aba yesto lai same banauna parxa

# %%
data['Education']= data['Education'].replace({
    "Bachelor's": 'Bachelors',
    "Bachelor's Degree" : 'Bachelors',
    "Master's": 'Masters',
     "Master's Degree": 'Masters',
    'PhD': 'phD'
})

# %%
data['Education'].unique()
# Out:
# array(['Bachelors', 'Masters', 'phD', 'High School'], dtype=object)

# %%
#Manually diney
#.map ra replace le autai kura ho 
#.map le string to integer ma lagne garxa
data['Education']= data['Education'].map({
    'High School':0,
    'Bachelors':1,
    'Masters':2,
    'phD':3
})

# %%
#data['Education']= data['Education'].replace({
   # 'High School':'0',
   # 'Bachelors':'1',
    #'Masters':'2',
    #'phD':'3'
})#replace ma pani string to integer lagna milxa
# Out:
# C:\Users\admin\AppData\Local\Temp\ipykernel_10096\1097315027.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   data['Education']= data['Education'].replace({

# %%
data.head()
# Out:
#     Age  Gender  Education          Job Title  Years of Experience    Salary
# 0  32.0    Male          1  Software Engineer                  5.0   90000.0
# 1  28.0  Female          2       Data Analyst                  3.0   65000.0
# 2  45.0    Male          3     Senior Manager                 15.0  150000.0
# 3  36.0  Female          1    Sales Associate                  7.0   60000.0
# 4  52.0    Male          2           Director                 20.0  200000.0

# %%
data.Education.unique()
# Out:
# array([1, 2, 3, 0])

# %% [markdown]
# # KNN

# %%
K nearest Neighbors

# %%
for two datapoints(x,y):(4,3)
Distance = sqrt((x2-x1)**2+(y2-y2)**2) : Euclidean distance formula/L2 norm

  (absolute value)       |x2-x2|+|y2-y2|:Manhattan Distane

# %%
for 3 data points(4,3,2):(x,y,z)

Distance = sqrt((x2-x1)**2+(y2-y2)**2+(z2-z1)**2):Euclidean distance formula/L2 norm

  (absolute value)       |x2-x2|+|y2-y2|+|z2-z1|:Manhattan Distane

# %%
K ko value balanced lina paryo tesko lahi 2 3 try garera liney

# %%
Minkwoshi distance: 
:p=1 bhayo vane it represent Manhattan distance
p=2 bhayo bhane , it represent Eculidean distance

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, accuracy_score
from sklearn.neighbors import KNeighborsClassifier
import seaborn as sns

# %%
data = sns.load_dataset('iris')

# %%
sns.get_dataset_names() # seaborn ma already available vako dataset yo use garna milyo
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'dowjones',
#  'exercise',
#  'flights',
#  'fmri',
#  'geyser',
#  'glue',
#  'healthexp',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'seaice',
#  'taxis',
#  'tips',
#  'titanic']

# %%
data.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
X = data.drop('species', axis = 1)
y= data.species

# %%
xtrain,xtest,ytrain,ytest = train_test_split(X,y, test_size = 0.2, random_state = 4)

# %%
#n_neighbor bhaneko k ko value deko ho
#p=2 default linxa yesle ie euclidean distance linxa as a default distance
knn = KNeighborsClassifier(n_neighbors=9)
knn.fit(xtrain,ytrain)
# Out:
# KNeighborsClassifier(n_neighbors=9)

# %%
help(KNeighborsClassifier)
# Out:
# Help on class KNeighborsClassifier in module sklearn.neighbors._classification:
#
# class KNeighborsClassifier(sklearn.neighbors._base.KNeighborsMixin, sklearn.base.ClassifierMixin, sklearn.neighbors._base.NeighborsBase)
#  |  KNeighborsClassifier(
#  |      n_neighbors=5,
#  |      *,
#  |      weights='uniform',
#  |      algorithm='auto',
#  |      leaf_size=30,
#  |      p=2,
#  |      metric='minkowski',
#  |      metric_params=None,
#  |      n_jobs=None
#  |  )
#  |
#  |  Classifier implementing the k-nearest neighbors vote.
#  |
#  |  Read more in the :ref:`User Guide <classification>`.
#  |
#  |  Parameters
#  |  ----------
#  |  n_neighbors : int, default=5
#  |      Number of neighbors to use by default for :meth:`kneighbors` queries.
#  |
#  |  weights : {'uniform', 'distance'}, callable or None, default='uniform'
#  |      Weight function used in prediction.  Possible values:
#  |
#  |      - 'uniform' : uniform weights.  All points in each neighborhood
# ...

# %%
yprediction = knn.predict(xtest)
yprediction
# Out:
# array(['virginica', 'setosa', 'virginica', 'virginica', 'virginica',
#        'versicolor', 'virginica', 'setosa', 'setosa', 'virginica',
#        'setosa', 'setosa', 'setosa', 'versicolor', 'virginica', 'setosa',
#        'versicolor', 'setosa', 'setosa', 'virginica', 'setosa',
#        'virginica', 'versicolor', 'setosa', 'setosa', 'setosa', 'setosa',
#        'setosa', 'setosa', 'virginica'], dtype=object)

# %%
#Accuarcy
accuracy = accuracy_score(ytest,yprediction)
print(f'Accuracy:{accuracy:.2%}')
# Out:
# Accuracy:96.67%

# %% [markdown]
# # DataScaling

# %%
DataScaling: knn ma paila scaling garera matra model fit garna parxa
label encoding using scikitlearn
