# %%
#Logistic Regression: classifiction ko lagi use hunxa

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('diabetes.csv')
data
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
# 768            0      123             77              0        1  36.3
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# ...

# %%
age bata diabetes predict garbe using logistic regrssion

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 769 entries, 0 to 768
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Pregnancies               769 non-null    int64
#  1   Glucose                   769 non-null    int64
#  2   BloodPressure             769 non-null    int64
#  3   SkinThickness             769 non-null    int64
#  4   Insulin                   769 non-null    int64
#  5   BMI                       769 non-null    float64
#  6   DiabetesPedigreeFunction  769 non-null    float64
#  7   Age                       769 non-null    int64
#  8   Outcome                   769 non-null    int64
# dtypes: float64(2), int64(7)
# memory usage: 54.2 KB

# %%
data.describe()
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   769.000000  769.000000     769.000000     769.000000  769.000000
# mean      3.840052  120.897269      69.115735      20.509753   79.697009
# std       3.370237   31.951886      19.345296      15.959020  115.203999
# min       0.000000    0.000000       0.000000       0.000000    0.000000
# 25%       1.000000   99.000000      62.000000       0.000000    0.000000
# 50%       3.000000  117.000000      72.000000      23.000000   29.000000
# 75%       6.000000  140.000000      80.000000      32.000000  127.000000
# max      17.000000  199.000000     122.000000      99.000000  846.000000
#
#               BMI  DiabetesPedigreeFunction         Age     Outcome
# count  769.000000                769.000000  769.000000  769.000000
# mean    31.998179                  0.471590   33.269181    0.349805
# std      7.880557                  0.331208   11.778737    0.477219
# ...

# %%
data.isnull().sum()
# Out:
# Pregnancies                 0
# Glucose                     0
# BloodPressure               0
# SkinThickness               0
# Insulin                     0
# BMI                         0
# DiabetesPedigreeFunction    0
# Age                         0
# Outcome                     0
# dtype: int64

# %%
X = data[['Age']]
y= data.Outcome

# %%
#logistic regrssion le pani line nai fit garxa tara aba line ma herera predict garne haina 0 ra 1 ko formma predict garne ho line le dine value lai function lagayera 0 ra 1 ko value dinxa

# %%
plt.scatter(data.Age,data.Outcome)
plt.xlabel('Age')
plt.ylabel('Outcome')
plt.show()

# %%
#equation
z = b0+b1x paila z ko value nikalxa ra sigmoid vane function use garera value nikalxa , sigmoid ko value line ma pass gardinxa
sigmoid funcion: y = sigmoid(z)1/1+e^z

# %%
#linear regrssion nai garne ho garna chai tes bata ako y ko value as a z mane ra z ko valeu funtion ma halne ra tyo value lai 0 ra 1 ko form ma dinxa

# %%
z = b0+b1x
y = sigmoid function(z)
#sigmoid le probability ho deko
#equation of sigmoid: 1/(1+e^-z) 0 ra 1 ko bich ma value dinxa value le deko 0.5 vanda badi xa bhane class 1 predict hunxa ra 0.5 ayo bhane threshold 0 predict hunxa

# %%
xtrain,xtest, ytrain,ytest = train_test_split(X,y ,test_size = 0.2, random_state = 25)

# %%
log_model = LogisticRegression()
log_model.fit(xtrain,ytrain)
# Out:
# LogisticRegression()

# %%
pred_new = pd.DataFrame({
    'Age':[50]
})

# %%
#prediction
#age = 40

print(log_model.predict(pred_new))
# Out:
# [1]

# %%
print(log_model.predict_proba(pred_new))
# Out:
# [[0.49807728 0.50192272]]

# %%
#Evalution 
#ahile ko casema target variable 0 ra 1 xa ki 0 predict garxa ki1 garxa

# %%
Actual                      prediction
0                              0 -correct
0                              1 incorrect
1                              0 incorrect
1                               1 correct
# yetiko basis ma evaluate garna parxa ra count garxan kati ota correct ayo kati ota incorrect ayo banera

# %%
# prediction ko lagi xtest linxa
xtest.shape
# Out:
# (154, 1)

# %%
0   0 correct
1   1 correct

0    1 incorrect
1    0 incorrect

# %%
# auta row ma predicted ko count rakxam ra arko tira actaul ko count rakxxam: confusion matrix

# %%
yprediction = log_model.predict(xtest)

# %%
ytest
# Out:
# 380    0
# 39     1
# 346    0
# 416    0
# 648    1
#       ..
# 396    0
# 153    0
# 531    0
# 448    1
# 190    0
# Name: Outcome, Length: 154, dtype: int64

# %%
from sklearn.metrics import confusion_matrix, accuracy_score

# %%
accuracy = accuracy_score(ytest, yprediction) # test data ko accuarcy patta lagako
print(accuracy)
# Out:
# 0.6948051948051948

# %%
print(f'Accuracy:{accuracy:.2%}') # accuracy derai ako ramro
# Out:
# Accuracy:69.48%

# %% [markdown]
# # Confusion Matrix

# %%
cm = confusion_matrix(ytest, yprediction)
cm
# Out:
# array([[97,  8],
#        [39, 10]])
