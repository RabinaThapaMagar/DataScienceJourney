# %%
KNN
-distance based algorithm
-value of k=5 xa bhane to 5 min distance vako data lagxa, number of neighbors
-Top 5 minimun distance

# %% [markdown]
# # DataScaling
# # Label Encoding

# %%
#Label Encoding: scikit learn bara ni garna sakinxa
LabelEncoder le 0 1 ko form ma dinxa map gare jasari

# %%
import pandas as pd
from sklearn.preprocessing import LabelEncoder
import seaborn as sns

# %%
df = sns.load_dataset('iris')
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
#species ma label encoding lagauna parxa kinaki sabai aru data numeric mai xa

# %%
#.fit_transform()
encoder = LabelEncoder() # object banako
df['Label'] = encoder.fit_transform(df.species)

# %%
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species  Label
# 0             5.1          3.5           1.4          0.2     setosa      0
# 1             4.9          3.0           1.4          0.2     setosa      0
# 2             4.7          3.2           1.3          0.2     setosa      0
# 3             4.6          3.1           1.5          0.2     setosa      0
# 4             5.0          3.6           1.4          0.2     setosa      0
# ..            ...          ...           ...          ...        ...    ...
# 145           6.7          3.0           5.2          2.3  virginica      2
# 146           6.3          2.5           5.0          1.9  virginica      2
# 147           6.5          3.0           5.2          2.0  virginica      2
# 148           6.2          3.4           5.4          2.3  virginica      2
# 149           5.9          3.0           5.1          1.8  virginica      2
#
# [150 rows x 6 columns]

# %%
encoder.classes_
# Out:
# array(['setosa', 'versicolor', 'virginica'], dtype=object)

# %%
df.Label.unique() # setosa lai 0 , versicolor lai 1 ra virginica lai 2 assign garyo
# Out:
# array([0, 1, 2])

# %%
#same yehi kaam map use garera garim
#agdi y banauda species leko thim tara aile label line
#alphabetical order ma assign gardinxa yo label encoder function le map le testo gardaina
#order chaheko xa bhane map nai use garda thik hunxa tara order chaheko xaina bhane label encoder nai laune

# %% [markdown]
# # DataScaling

# %%
Scaling: data ko range xutta xuttai xa bhane scaling garna parxa jastai data haru lai same range ma launu bhakeko datascalimg ho
high range ko data lai same range ma laune

# %%
1. Minmax Scaling
xscaled = x-xmin/xmax-xmin   (0-1)range 

(0-5) 
     xnew_min +  (x-xmin)/(xmax-xmin) *(xnew_max-xnew_min)

# %%
(x-xmin)/(xmax-xmin) -

# %%
2. z-score Normalization
   xscaled = x - min/std

# %%
data = pd.read_csv('Diabetes.csv')
data.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
data.describe()
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   769.000000  769.000000     769.000000     769.000000  769.000000
# mean      3.840052  120.897269      69.115735      20.509753   79.697009
# std       3.370237   31.951886      19.345296      15.959020  115.203999
# min       0.000000    0.000000       0.000000       0.000000    0.000000
# 25%       1.000000   99.000000      62.000000       0.000000    0.000000
# 50%       3.000000  117.000000      72.000000      23.000000   29.000000
# 75%       6.000000  140.000000      80.000000      32.000000  127.000000
# max      17.000000  199.000000     122.000000      99.000000  846.000000
#
#               BMI  DiabetesPedigreeFunction         Age     Outcome
# count  769.000000                769.000000  769.000000  769.000000
# mean    31.998179                  0.471590   33.269181    0.349805
# std      7.880557                  0.331208   11.778737    0.477219
# ...

# %%
# ana scaling garna parxa

# %%
from sklearn.preprocessing import MinMaxScaler, StandardScaler
from sklearn.model_selection import train_test_split

# %%
#Note
Scaling is done after train-test split

# %%
X = data[['Glucose','Age']]
y = data.Outcome

# %%
xtrain,xtest,ytrain,ytest = train_test_split(X,y, test_size = 0.2, random_state = 9)

# %%
#StandardScalar

# %%
scaler = StandardScaler()
data['BloodPressure'] = scaler.fit_transform(data[['BloodPressure']])

# %%
data.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148       0.149191             35        0  33.6
# 1            1       85      -0.161164             29        0  26.6
# 2            8      183      -0.264615              0        0  23.3
# 3            1       89      -0.161164             23       94  28.1
# 4            0      137      -1.506035             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
data.describe()
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   769.000000  769.000000   7.690000e+02     769.000000  769.000000
# mean      3.840052  120.897269  -1.755567e-16      20.509753   79.697009
# std       3.370237   31.951886   1.000651e+00      15.959020  115.203999
# min       0.000000    0.000000  -3.575066e+00       0.000000    0.000000
# 25%       1.000000   99.000000  -3.680670e-01       0.000000    0.000000
# 50%       3.000000  117.000000   1.491909e-01      23.000000   29.000000
# 75%       6.000000  140.000000   5.629973e-01      32.000000  127.000000
# max      17.000000  199.000000   2.735481e+00      99.000000  846.000000
#
#               BMI  DiabetesPedigreeFunction         Age     Outcome
# count  769.000000                769.000000  769.000000  769.000000
# mean    31.998179                  0.471590   33.269181    0.349805
# std      7.880557                  0.331208   11.778737    0.477219
# ...

# %%
df = pd.read_csv('Diabetes.csv')
df.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
#aba minmax scaling lagaune yesle 0 ra 1 range ma dinxa

# %%
minmax = MinMaxScaler()
df['BloodPressure']= minmax.fit_transform(df[['BloodPressure']])

# %%
df.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148       0.590164             35        0  33.6
# 1            1       85       0.540984             29        0  26.6
# 2            8      183       0.524590              0        0  23.3
# 3            1       89       0.540984             23       94  28.1
# 4            0      137       0.327869             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
df.describe()
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   769.000000  769.000000     769.000000     769.000000  769.000000
# mean      3.840052  120.897269       0.566522      20.509753   79.697009
# std       3.370237   31.951886       0.158568      15.959020  115.203999
# min       0.000000    0.000000       0.000000       0.000000    0.000000
# 25%       1.000000   99.000000       0.508197       0.000000    0.000000
# 50%       3.000000  117.000000       0.590164      23.000000   29.000000
# 75%       6.000000  140.000000       0.655738      32.000000  127.000000
# max      17.000000  199.000000       1.000000      99.000000  846.000000
#
#               BMI  DiabetesPedigreeFunction         Age     Outcome
# count  769.000000                769.000000  769.000000  769.000000
# mean    31.998179                  0.471590   33.269181    0.349805
# std      7.880557                  0.331208   11.778737    0.477219
# ...

# %%
df = pd.read_csv('Diabetes.csv')
df.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
minmax = MinMaxScaler(feature_range=(2,5)) # 2 dekhi 5 samma ko range deko manually
df['BloodPressure']=minmax.fit_transform(df[['BloodPressure']])

# %%
df.describe() # ie min ma 2 ra max ma 5 samma ko xa blood pressure ma
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   769.000000  769.000000     769.000000     769.000000  769.000000
# mean      3.840052  120.897269       3.699567      20.509753   79.697009
# std       3.370237   31.951886       0.475704      15.959020  115.203999
# min       0.000000    0.000000       2.000000       0.000000    0.000000
# 25%       1.000000   99.000000       3.524590       0.000000    0.000000
# 50%       3.000000  117.000000       3.770492      23.000000   29.000000
# 75%       6.000000  140.000000       3.967213      32.000000  127.000000
# max      17.000000  199.000000       5.000000      99.000000  846.000000
#
#               BMI  DiabetesPedigreeFunction         Age     Outcome
# count  769.000000                769.000000  769.000000  769.000000
# mean    31.998179                  0.471590   33.269181    0.349805
# std      7.880557                  0.331208   11.778737    0.477219
# ...

# %%
help(MinMaxScaler)
# Out:
# Help on class MinMaxScaler in module sklearn.preprocessing._data:
#
# class MinMaxScaler(sklearn.base.OneToOneFeatureMixin, sklearn.base.TransformerMixin, sklearn.base.BaseEstimator)
#  |  MinMaxScaler(feature_range=(0, 1), *, copy=True, clip=False)
#  |
#  |  Transform features by scaling each feature to a given range.
#  |
#  |  This estimator scales and translates each feature individually such
#  |  that it is in the given range on the training set, e.g. between
#  |  zero and one.
#  |
#  |  The transformation is given by::
#  |
#  |      X_std = (X - X.min(axis=0)) / (X.max(axis=0) - X.min(axis=0))
#  |      X_scaled = X_std * (max - min) + min
#  |
#  |  where min, max = feature_range.
#  |
#  |  This transformation is often used as an alternative to zero mean,
#  |  unit variance scaling.
#  |
#  |  `MinMaxScaler` doesn't reduce the effect of outliers, but it linearly
#  |  scales them down into a fixed range, where the largest occurring data point
# ...

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.neighbors import KNeighborsClassifier
import pandas as pd

# %%
data = pd.read_csv('Diabetes.csv')
data.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
X = data[['Glucose', 'Age']]
y = data.Outcome

# %%
X # duitai korange farak xa so range same banauna paryo
# Out:
#      Glucose  Age
# 0        148   50
# 1         85   31
# 2        183   32
# 3         89   21
# 4        137   33
# ..       ...  ...
# 764      122   27
# 765      121   30
# 766      126   47
# 767       93   23
# 768      123   55
#
# [769 rows x 2 columns]

# %%
xtrain, xtest, ytrain, ytest = train_test_split(X,y, test_size = 0.2, random_state = 9)

# %%
xtest
# Out:
#      Glucose  Age
# 456      135   62
# 260      191   34
# 651      117   27
# 143      108   42
# 666      145   70
# ..       ...  ...
# 583      100   42
# 586      143   41
# 478      126   39
# 655      155   25
# 32        88   22
#
# [154 rows x 2 columns]

# %%
#mean ra sd traiing ko data bata nai nikalne test data chai pure nai huna parxa
training data kai mean ra sd use garera testing ma transform matra garxam
#scaling jaile xtrain ra xtest lai garne ho y lai garidaina
testing ko kunai data training ma jana vayena scaling garda jaile pani

# %%
Glucose : standardScaler: x-mean/std
age: StandardScaler: x-mean/std

# %%
xtrain_s = scaler.fit_transform(xtrain)
xtest_s = scaler.transform(xtest)

# %%
scaler = StandardScaler()
xnew = scaler.fit_transform(x)

# %%
#fit ma duita operation xa
.fit(): standard scaling lai chahine mean ra std calculate garera rakhxa   mean, sd
.transform(): typ ako mean ra std lagayera scaling garxa  x-mean/std

# %%
xtrain_s # glucose ra age duitai scaling vako xa
# Out:
# array([[-0.51263614, -0.3691081 ],
#        [-0.5444015 , -0.95416347],
#        [-1.43383166,  0.63384396],
#        ...,
#        [-0.76675904, -0.11837009],
#        [-0.70322832, -0.61984612],
#        [-0.38557469, -1.03774281]], shape=(615, 2))

# %%
xtest_s
 # test data ko pani scaling cvako xa jasma training kai mean ra std bata scaking gareko afno testing ko data use gardaina
# Out:
# array([[ 0.44032474,  2.38901006],
#        [ 2.21918506,  0.04878859],
#        [-0.13145179, -0.53626678],
#        [-0.41734005,  0.7174233 ],
#        [ 0.75797837,  3.05764477],
#        [-0.67146295,  0.7174233 ],
#        [-0.2902786 , -0.78700479],
#        [-0.83028977, -0.53626678],
#        [ 0.53562083, -1.03774281],
#        [-1.30677021, -0.95416347],
#        [-1.46559702, -0.03479075],
#        [-0.22674787, -0.78700479],
#        [-0.76675904, -0.28552876],
#        [ 0.31326329, -0.95416347],
#        [-0.67146295, -0.45268744],
#        [-0.83028977,  0.21594727],
#        [-0.32204396,  1.88753403],
#        [ 1.74270462,  1.55321668],
#        [-0.98911658, -0.70342546],
#        [-1.30677021, -1.03774281],
#        [-0.13145179,  0.55026462],
#        [-0.38557469,  2.22185139],
#        [-0.98911658, -0.78700479],
#        [-0.70322832, -0.11837009],
#        [-0.60793223,  0.21594727],
#        [-0.7985244 , -0.53626678],
#        [ 1.26622418,  1.13531999],
# ...

# %%
y lai scaling chahidaina
