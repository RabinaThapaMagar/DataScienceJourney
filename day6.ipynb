# %%
import pandas as pd

# %%
data = pd.read_csv('test.csv')

# %%
print(data)
# Out:
#      PassengerId  Pclass                                          Name  \
# 0            892       3                              Kelly, Mr. James
# 1            893       3              Wilkes, Mrs. James (Ellen Needs)
# 2            894       2                     Myles, Mr. Thomas Francis
# 3            895       3                              Wirz, Mr. Albert
# 4            896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# ..           ...     ...                                           ...
# 413         1305       3                            Spector, Mr. Woolf
# 414         1306       1                  Oliva y Ocana, Dona. Fermina
# 415         1307       3                  Saether, Mr. Simon Sivertsen
# 416         1308       3                           Ware, Mr. Frederick
# 417         1309       3                      Peter, Master. Michael J
#
#         Sex   Age  SibSp  Parch              Ticket      Fare Cabin Embarked
# ...

# %%
#See the first 15 entities
data.head(15)
# Out:
#     PassengerId  Pclass                                               Name  \
# 0           892       3                                   Kelly, Mr. James
# 1           893       3                   Wilkes, Mrs. James (Ellen Needs)
# 2           894       2                          Myles, Mr. Thomas Francis
# 3           895       3                                   Wirz, Mr. Albert
# 4           896       3       Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# 5           897       3                         Svensson, Mr. Johan Cervin
# 6           898       3                               Connolly, Miss. Kate
# 7           899       2                       Caldwell, Mr. Albert Francis
# 8           900       3          Abrahim, Mrs. Joseph (Sophie Halaut Easu)
# 9           901       3                            Davies, Mr. John Samuel
# 10          902       3                                   Ilieff, Mr. Ylio
# ...

# %%
#See the last 15 entities
data.tail(15)
# Out:
#      PassengerId  Pclass                                             Name  \
# 403         1295       1                           Carrau, Mr. Jose Pedro
# 404         1296       1                     Frauenthal, Mr. Isaac Gerald
# 405         1297       2     Nourney, Mr. Alfred (Baron von Drachstedt")"
# 406         1298       2                        Ware, Mr. William Jeffery
# 407         1299       1                       Widener, Mr. George Dunton
# 408         1300       3                  Riordan, Miss. Johanna Hannah""
# 409         1301       3                        Peacock, Miss. Treasteall
# 410         1302       3                           Naughton, Miss. Hannah
# 411         1303       1  Minahan, Mrs. William Edward (Lillian E Thorpe)
# 412         1304       3                   Henriksson, Miss. Jenny Lovisa
# 413         1305       3                               Spector, Mr. Woolf
# 414         1306       1                     Oliva y Ocana, Dona. Fermina
# ...

# %%
#find shape of the dataset
data.shape
# Out:
# (418, 11)

# %%
#find number of columns in dataset
data = pd.read_csv('test.csv').shape[0]
print(data)
# Out:
# 418

# %%
#find number of rows in dataset
data = pd.read_csv('test.csv').shape[1]
print(data)
# Out:
# 11

# %%
#another method of finding number of rows in dataset
data.shape[0]
# Out:
# 418

# %%
#another method of finding number of columns in dataset
data.shape[1]
# Out:
# 11

# %%
#printing the all name of columns
print(data.columns)
# Out:
# Index(['PassengerId', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp', 'Parch',
#        'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
#printing only the Pclass columns
print(data['Pclass'])
# Out:
# 0      3
# 1      3
# 2      2
# 3      3
# 4      3
#       ..
# 413    3
# 414    1
# 415    3
# 416    3
# 417    3
# Name: Pclass, Length: 418, dtype: int64

# %%
#Number of Pclass values
unique_pclass = data['Pclass'].nunique()
print("Number of different pclass values:", unique_pclass)
# Out:
# Number of different pclass values: 3

# %%
data['Pclass'].unique()
# Out:
# array([3, 2, 1])

# %%
#Different values of Pclass
print(data['Pclass'].value_counts())
# Out:
# Pclass
# 3    218
# 1    107
# 2     93
# Name: count, dtype: int64

# %%
#summarize the dataset using describe function
data.describe()
# Out:
#        PassengerId      Pclass         Age       SibSp       Parch        Fare
# count   418.000000  418.000000  332.000000  418.000000  418.000000  417.000000
# mean   1100.500000    2.265550   30.272590    0.447368    0.392344   35.627188
# std     120.810458    0.841838   14.181209    0.896760    0.981429   55.907576
# min     892.000000    1.000000    0.170000    0.000000    0.000000    0.000000
# 25%     996.250000    1.000000   21.000000    0.000000    0.000000    7.895800
# 50%    1100.500000    3.000000   27.000000    0.000000    0.000000   14.454200
# 75%    1204.750000    3.000000   39.000000    1.000000    0.000000   31.500000
# max    1309.000000    3.000000   76.000000    8.000000    9.000000  512.329200

# %%
# Summarize only the 'age' column
age_summary = data['Age'].describe()
print(age_summary)
# Out:
# count    332.000000
# mean      30.272590
# std       14.181209
# min        0.170000
# 25%       21.000000
# 50%       27.000000
# 75%       39.000000
# max       76.000000
# Name: Age, dtype: float64

# %%
#mean age of passenger
mean_age = data['Age'].mean()

print("Mean age of passengers:", mean_age)
# Out:
# Mean age of passengers: 30.272590361445783

# %%
data['Embarked'].nunique()
# Out:
# 3

# %%
data['Embarked'].unique()
# Out:
# array(['Q', 'S', 'C'], dtype=object)

# %%
mean_age = data['Age'].median()
print(mean_age)
# Out:
# 27.0

# %%
mean_age = data['Age'].mode()#mode bhaneko most repeated value
print(mean_age)
# Out:
# 0    21.0
# 1    24.0
# Name: Age, dtype: float64

# %%
#Use index on the basis of conditions day6

# %%
data.loc[10] # particular row or column accesss garne
# Out:
# PassengerId                 902
# Pclass                        3
# Name           Ilieff, Mr. Ylio
# Sex                        male
# Age                         NaN
# SibSp                         0
# Parch                         0
# Ticket                   349220
# Fare                     7.8958
# Cabin                       NaN
# Embarked                      S
# Name: 10, dtype: object

# %%
data.loc[5:10]
# Out:
#     PassengerId  Pclass                                       Name     Sex  \
# 5           897       3                 Svensson, Mr. Johan Cervin    male
# 6           898       3                       Connolly, Miss. Kate  female
# 7           899       2               Caldwell, Mr. Albert Francis    male
# 8           900       3  Abrahim, Mrs. Joseph (Sophie Halaut Easu)  female
# 9           901       3                    Davies, Mr. John Samuel    male
# 10          902       3                           Ilieff, Mr. Ylio    male
#
#      Age  SibSp  Parch     Ticket     Fare Cabin Embarked
# 5   14.0      0      0       7538   9.2250   NaN        S
# 6   30.0      0      0     330972   7.6292   NaN        Q
# 7   26.0      1      1     248738  29.0000   NaN        S
# 8   18.0      0      0       2657   7.2292   NaN        C
# 9   21.0      2      0  A/4 48871  24.1500   NaN        S
# 10   NaN      0      0     349220   7.8958   NaN        S

# %%
#age 40 hune ho rows ie data chahiyo ie kunia condition ko basis ma tyo rows haru chahiyo

# %%
#display those rows/data whose Age = 40 # condition ko case ma loc ,iloc use nagarera yesari use garne
#row ko data index bata nai acces garinxa
#row - index
data.Age
data['Age'] # both are same

# %%
data[data.Age == 40] # 40 age vako value haru
# Out:
#      PassengerId  Pclass                                        Name   Sex  \
# 139         1031       3              Goodwin, Mr. Charles Frederick  male
# 174         1066       3  Asplund, Mr. Carl Oscar Vilhelm Gustafsson  male
# 185         1077       2                   Maybery, Mr. Frank Hubert  male
# 189         1081       2                             Veal, Mr. James  male
# 277         1169       2                       Faunthorpe, Mr. Harry  male
#
#       Age  SibSp  Parch   Ticket     Fare Cabin Embarked
# 139  40.0      1      6  CA 2144  46.9000   NaN        S
# 174  40.0      1      5   347077  31.3875   NaN        S
# 185  40.0      0      0   239059  16.0000   NaN        S
# 189  40.0      0      0    28221  13.0000   NaN        S
# 277  40.0      1      0     2926  26.0000   NaN        S

# %%
#same kaam query bata ni garna sakina autai kaam ko lagi derai function haru hunxa python ma
data.query('Age==40')
# Out:
#      PassengerId  Pclass                                        Name   Sex  \
# 139         1031       3              Goodwin, Mr. Charles Frederick  male
# 174         1066       3  Asplund, Mr. Carl Oscar Vilhelm Gustafsson  male
# 185         1077       2                   Maybery, Mr. Frank Hubert  male
# 189         1081       2                             Veal, Mr. James  male
# 277         1169       2                       Faunthorpe, Mr. Harry  male
#
#       Age  SibSp  Parch   Ticket     Fare Cabin Embarked
# 139  40.0      1      6  CA 2144  46.9000   NaN        S
# 174  40.0      1      5   347077  31.3875   NaN        S
# 185  40.0      0      0   239059  16.0000   NaN        S
# 189  40.0      0      0    28221  13.0000   NaN        S
# 277  40.0      1      0     2926  26.0000   NaN        S

# %% [markdown]
# # Exploratory Data Anlaysis

# %%
data = pd.read_csv('Salary_Data.csv')
print(data)
# Out:
#       Age  Gender Education Level                      Job Title  \
# 0    32.0    Male      Bachelor's              Software Engineer
# 1    28.0  Female        Master's                   Data Analyst
# 2    45.0    Male             PhD                 Senior Manager
# 3    36.0  Female      Bachelor's                Sales Associate
# 4    52.0    Male        Master's                       Director
# ..    ...     ...             ...                            ...
# 370  35.0  Female      Bachelor's       Senior Marketing Analyst
# 371  43.0    Male        Master's         Director of Operations
# 372  29.0  Female      Bachelor's         Junior Project Manager
# 373  34.0    Male      Bachelor's  Senior Operations Coordinator
# 374  44.0  Female             PhD        Senior Business Analyst
#
#      Years of Experience    Salary
# 0                    5.0   90000.0
# 1                    3.0   65000.0
# 2                   15.0  150000.0
# 3                    7.0   60000.0
# ...

# %%
data['Education Level'].unique()
# Out:
# array(["Bachelor's", "Master's", 'PhD', nan], dtype=object)

# %% [markdown]
# # Plots

# %%
#Barplot
#histogram/kdeplot
#scatterplot
#boxPlot

# %%
#data ma issues haru huna sakxa data read garisake paxi data cleaning step garna parxa jastai not null value ako thyo
#Issues in data
#1.missing values ie data nai navako
#2.Non-standard/ Inconsistency ie data farak khaal ko xa
#nan values haru ako xa bhane ie missing value entry nai navako value ie cabin ma nan xa mathi

# %%
#Matplot
#Seaborn

# %%
#data load garera explore garxam data lai isssues haru vetinxa ra data lai clean pani garxam ra pheri eda ko process garxam

# %%
#handling nan or missing values (.isnull) yo baneko data null xa kin xaina banera true ir false ma answer dinxa
data.isnull()
# Out:
#        Age  Gender  Education Level  Job Title  Years of Experience  Salary
# 0    False   False            False      False                False   False
# 1    False   False            False      False                False   False
# 2    False   False            False      False                False   False
# 3    False   False            False      False                False   False
# 4    False   False            False      False                False   False
# ..     ...     ...              ...        ...                  ...     ...
# 370  False   False            False      False                False   False
# 371  False   False            False      False                False   False
# 372  False   False            False      False                False   False
# 373  False   False            False      False                False   False
# 374  False   False            False      False                False   False
#
# [375 rows x 6 columns]

# %%
#ka nira trur xa vanera kojna lai
data.isnull().sum()
# Out:
# Age                    2
# Gender                 2
# Education Level        2
# Job Title              2
# Years of Experience    2
# Salary                 2
# dtype: int64

# %%
#kun kun rows ma kasari data basexa banera herna ni sakinxa
data[data.isnull().any(axis = 1)] # yo rows haru ma null values matra dinxa
# Out:
#      Age Gender Education Level Job Title  Years of Experience  Salary
# 172  NaN    NaN             NaN       NaN                  NaN     NaN
# 260  NaN    NaN             NaN       NaN                  NaN     NaN

# %%
#any auta matra missing xa bhane ni any le dinxa
#all

# %%
data[data.isnull().all(axis = 1)] # jasko sabai values missing xa tyo value dinxa
# Out:
#      Age Gender Education Level Job Title  Years of Experience  Salary
# 172  NaN    NaN             NaN       NaN                  NaN     NaN
# 260  NaN    NaN             NaN       NaN                  NaN     NaN

# %%
#hamle any herna paryo
#axis = 0 le row represnt garxa
#axis = 1 le column represent garxa

# %%
#Handling missing values
#fill:null xa bahne keu value le fill pani garna sakxam ie mean value le fill gardina sakxam baaki vako data ko mean nikalera fill gardine, kunai ma mean le kunai ma medianle ra mode le ni fill garna sakinxa
#mean(),median(),mode(),forwardfill(),backwardfill(),nearestvalue(),
#forward fill: tyo vanda agdi ko value le replace gardinxa
#backward fill: pachadi ko value le fill gardine
#nearestvalue:arko row or column kojinxa jasto value similar hunxa 

#drop: if any column most of the values are missing hamro analysis ma derai significance role xaina so column lai remove gardina salxam ie remove column
#enough data xa bhane ra thorai nan value xa bhane remove that row

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 375 entries, 0 to 374
# Data columns (total 6 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Age                  373 non-null    float64
#  1   Gender               373 non-null    object
#  2   Education Level      373 non-null    object
#  3   Job Title            373 non-null    object
#  4   Years of Experience  373 non-null    float64
#  5   Salary               373 non-null    float64
# dtypes: float64(3), object(3)
# memory usage: 17.7+ KB

# %%
#age ma 373 ma null xaina bhanera deko xa

# %%
data.describe()
# Out:
#               Age  Years of Experience         Salary
# count  373.000000           373.000000     373.000000
# mean    37.431635            10.030831  100577.345845
# std      7.069073             6.557007   48240.013482
# min     23.000000             0.000000     350.000000
# 25%     31.000000             4.000000   55000.000000
# 50%     36.000000             9.000000   95000.000000
# 75%     44.000000            15.000000  140000.000000
# max     53.000000            25.000000  250000.000000

# %%
#describe ma pani age ko count ma thora i value xa

# %%
#plot banaunda missing value le issues dinxa so clean garna parxa

# %%
#functions
data.dropna()# ja nira data missing vetxa tyo row haruu delete gardinxa tara actual ma delete gareko hudaina data ni katai assign gareko hudaina
# Out:
#       Age  Gender Education Level                      Job Title  \
# 0    32.0    Male      Bachelor's              Software Engineer
# 1    28.0  Female        Master's                   Data Analyst
# 2    45.0    Male             PhD                 Senior Manager
# 3    36.0  Female      Bachelor's                Sales Associate
# 4    52.0    Male        Master's                       Director
# ..    ...     ...             ...                            ...
# 370  35.0  Female      Bachelor's       Senior Marketing Analyst
# 371  43.0    Male        Master's         Director of Operations
# 372  29.0  Female      Bachelor's         Junior Project Manager
# 373  34.0    Male      Bachelor's  Senior Operations Coordinator
# 374  44.0  Female             PhD        Senior Business Analyst
#
#      Years of Experience    Salary
# 0                    5.0   90000.0
# 1                    3.0   65000.0
# 2                   15.0  150000.0
# 3                    7.0   60000.0
# ...

# %%
data.shape # delete garda ni shape herda full pailakai data dekhai raxa 373 dekhayo 375 data xa
#
# Out:
# (375, 6)

# %%
#tyo delete garne lai value lai assign ni huunxqa
data = data.dropna()

# %%
data.dropna(inplace=True) # original data xa tesbata nai drop gardine view matra nagarne

# %%
df = data.dropna() # delete vako data haru df ma gayera basxa
#cleanin gare paxi check pani garne

# %%
data.shape # aba chai hatyo actual data bata missing vale
# Out:
# (373, 6)

# %%
#particular datalai change garna lai
data
# Out:
#       Age  Gender Education Level                      Job Title  \
# 0    32.0    Male      Bachelor's              Software Engineer
# 1    28.0  Female        Master's                   Data Analyst
# 2    45.0    Male             PhD                 Senior Manager
# 3    36.0  Female      Bachelor's                Sales Associate
# 4    52.0    Male        Master's                       Director
# ..    ...     ...             ...                            ...
# 370  35.0  Female      Bachelor's       Senior Marketing Analyst
# 371  43.0    Male        Master's         Director of Operations
# 372  29.0  Female      Bachelor's         Junior Project Manager
# 373  34.0    Male      Bachelor's  Senior Operations Coordinator
# 374  44.0  Female             PhD        Senior Business Analyst
#
#      Years of Experience    Salary
# 0                    5.0   90000.0
# 1                    3.0   65000.0
# 2                   15.0  150000.0
# 3                    7.0   60000.0
# ...

# %%
#2 index ma vako value title correction garna paryo bhane tesko lagi row ra column dubai tira bata access garera change garna sakinxa
data.at[2,'Job Title']
# Out:
# 'Senior Manager'

# %%
#yeslai change garnalai senior managera bata seniorm banako
data.at[2,'Job Title'] = 'SeniorM'

# %%
data
# Out:
#       Age  Gender Education Level                      Job Title  \
# 0    32.0    Male      Bachelor's              Software Engineer
# 1    28.0  Female        Master's                   Data Analyst
# 2    45.0    Male             PhD                        SeniorM
# 3    36.0  Female      Bachelor's                Sales Associate
# 4    52.0    Male        Master's                       Director
# ..    ...     ...             ...                            ...
# 370  35.0  Female      Bachelor's       Senior Marketing Analyst
# 371  43.0    Male        Master's         Director of Operations
# 372  29.0  Female      Bachelor's         Junior Project Manager
# 373  34.0    Male      Bachelor's  Senior Operations Coordinator
# 374  44.0  Female             PhD        Senior Business Analyst
#
#      Years of Experience    Salary
# 0                    5.0   90000.0
# 1                    3.0   65000.0
# 2                   15.0  150000.0
# 3                    7.0   60000.0
# ...

# %% [markdown]
# # Barplot
# # histogram/kdeplot
# # scatterplot
# # boxPlot

# %%
pip install matplotlib
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# # Histogram : single numeric variable(column,attributes) ma use hunxa ex age ko lagi herna sakina
# # syntax of histogram : plt.hist(variable or column name dine)

# %%
plt.hist(data.Age,bins = 5 ) # afai yeti ko class bana vanera pani dina sakinxa bins = 5 banayera
plt.title('Histogram of Age')
plt.xlabel('Age')
plt.ylabel('Count')# hostogram is used to see the distribution of data
plt.show()

# %%
#bins afai class banayo histogram le teslai bins vanxa jastai 20 dekhi 25 samma
20-25:
25-30

# %%
# sabai particular ko yaad hudaina dcocumentationn herne
help(plt.hist)
# Out:
# Help on function hist in module matplotlib.pyplot:
#
# hist(
#     x: 'ArrayLike | Sequence[ArrayLike]',
#     bins: 'int | Sequence[float] | str | None' = None,
#     *,
#     range: 'tuple[float, float] | None' = None,
#     density: 'bool' = False,
#     weights: 'ArrayLike | None' = None,
#     cumulative: 'bool | float' = False,
#     bottom: 'ArrayLike | float | None' = None,
#     histtype: "Literal['bar', 'barstacked', 'step', 'stepfilled']" = 'bar',
#     align: "Literal['left', 'mid', 'right']" = 'mid',
#     orientation: "Literal['vertical', 'horizontal']" = 'vertical',
#     rwidth: 'float | None' = None,
#     log: 'bool' = False,
#     color: 'ColorType | Sequence[ColorType] | None' = None,
#     label: 'str | Sequence[str] | None' = None,
#     stacked: 'bool' = False,
#     data=None,
#     **kwargs
# ) -> 'tuple[np.ndarray | list[np.ndarray], np.ndarray, BarContainer | Polygon | list[BarContainer | Polygon]]'
#     Compute and plot a histogram.
#
# ...
