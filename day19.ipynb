# %%
#LinearRegression : Regression(numerical)
#LogisticRegression: classification(labaled data,binary,multi-class)
#KNN:for classification(Distance based)(Data Scaling)
#Decision Trees:Tree ko basis ma classification garxa

# %% [markdown]
# # SVM(Support Vector Machine)|

# %%
#linearly seperable: line le seperate garna sakxa bhane linearly seperable
#Linearly unseperable: line le seperate gardaina bhane it is calld linearly unseperable

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('Diabetes.csv')
df.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
X = df[['Glucose', 'Age']]
y= df.Outcome

# %%
plt.scatter(df.Glucose, df.Age)
plt.xlabel('Glucose')
plt.ylabel('Age')
plt.show()

# %%
#same code with scatter
#hue ma arko parambetr pass garna milxa
sns.scatterplot(data = df, x ='Glucose',y = 'Age',hue = 'Outcome')
plt.show()

# %%
#linearly seperacble xaina bhane logistic use garna mildaina yesm decision use garinxa

# %%
#Decicison Tree
#Ensemble 
#RandomForest
#SVM()

# %%
#SWM 
-linearly seperacle , if not oay
= no of rows < features

# %%
#SVM duita class ko bich ma line banaidxa 

-hyperplane sake samma margin maximun gardine wala optimal hyperolahe choose garna
-curve pani baanauna millxa yesma

# %%
#3D scatter for 3 dimensinal variables

# %%
#SVM

# %%
from sklearn.datasets  import __all__#datasets available here
print(__all__)
# Out:
# ['clear_data_home', 'dump_svmlight_file', 'fetch_20newsgroups', 'fetch_20newsgroups_vectorized', 'fetch_file', 'fetch_lfw_pairs', 'fetch_lfw_people', 'fetch_olivetti_faces', 'fetch_species_distributions', 'fetch_california_housing', 'fetch_covtype', 'fetch_rcv1', 'fetch_kddcup99', 'fetch_openml', 'get_data_home', 'load_diabetes', 'load_digits', 'load_files', 'load_iris', 'load_breast_cancer', 'load_linnerud', 'load_sample_image', 'load_sample_images', 'load_svmlight_file', 'load_svmlight_files', 'load_wine', 'make_biclusters', 'make_blobs', 'make_circles', 'make_classification', 'make_checkerboard', 'make_friedman1', 'make_friedman2', 'make_friedman3', 'make_gaussian_quantiles', 'make_hastie_10_2', 'make_low_rank_matrix', 'make_moons', 'make_multilabel_classification', 'make_regression', 'make_s_curve', 'make_sparse_coded_signal', 'make_sparse_spd_matrix', 'make_sparse_uncorrelated', 'make_spd_matrix', 'make_swiss_roll']

# %%
from sklearn.datasets import make_blobs

# %%
from sklearn.datasets import make_blobs

# %%
X,y = make_blobs(100, centers = 3,cluster_std = 0.5)

# %%
x1                 x2            y
Glucosennn          Age          Diabetes

# %%
df = pd.DataFrame(X, columns = ['G','A'])
df.head()
# Out:
#           G          A
# 0 -0.451234  -3.724445
# 1 -5.419729   9.476007
# 2 -5.038725  10.786527
# 3  4.981634   5.029735
# 4  0.041863  -3.563352

# %%
y
# Out:
# array([0, 2, 2, 1, 0, 2, 2, 0, 1, 2, 1, 0, 1, 2, 2, 0, 1, 2, 2, 0, 0, 2,
#        1, 2, 1, 1, 0, 2, 2, 1, 0, 1, 1, 1, 2, 1, 0, 2, 0, 2, 2, 2, 0, 2,
#        0, 2, 0, 1, 0, 1, 2, 2, 0, 0, 0, 1, 2, 0, 0, 2, 1, 0, 0, 0, 1, 0,
#        0, 0, 2, 1, 1, 0, 1, 0, 0, 1, 2, 1, 1, 2, 1, 2, 0, 1, 2, 0, 1, 1,
#        0, 2, 0, 1, 2, 1, 2, 2, 1, 1, 0, 1])

# %%
plt.scatter(X[:,0],X[:,1])
plt.show()

# %%
X,y = make_blobs(100, centers = 2,cluster_std = 0.5)

# %%
X
# Out:
# array([[  7.5602694 ,  -0.06384471],
#        [  3.59342072,   3.95422545],
#        [ -4.76266339,   4.99942033],
#        [  5.42471808,  -1.13647603],
#        [  9.76461229,   6.54862178],
#        [  7.61287571,  -1.31861632],
#        [  5.1060141 ,  -0.19490333],
#        [ -4.52184676,   4.66535918],
#        [  6.95041521,  -5.2029556 ],
#        [  3.78619969,   5.43903161],
#        [  7.65052177,   0.36842727],
#        [-10.46175228,  -4.13873826],
#        [-10.20030708,  -2.72171173],
#        [  3.73011742,   4.70943518],
#        [  5.92096722,  -0.73035212],
#        [  5.99738359,  -0.33575595],
#        [ -4.79267141,   4.87410239],
#        [ -4.24581309,   5.54616796],
#        [  7.10767762,  -5.50365497],
#        [  9.16310624,   6.74340795],
#        [-10.00439875,  -2.89758172],
#        [-10.68299887,  -4.20507462],
#        [  7.49454889,  -0.79816326],
#        [ -4.47055102,   5.7931508 ],
#        [  5.97230482,  -1.11560541],
# ...

# %%
df = pd.DataFrame(X, columns = ['G','A'])
df.head()
# Out:
#           G         A
# 0  7.560269 -0.063845
# 1  3.593421  3.954225
# 2 -4.762663  4.999420
# 3  5.424718 -1.136476
# 4  9.764612  6.548622

# %%
df1 = pd.

# %%
#conatenation function duita lai merger garxa
